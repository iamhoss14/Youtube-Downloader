# %%
# %pip install pytube

# %%
# %pip install pytube

# %%
from pytube import YouTube
YouTube('https://youtu.be/2lAe1cqCOXo').streams.first().download()
yt = YouTube('http://youtube.com/watch?v=2lAe1cqCOXo')
yt.streams
filter(progressive=True, file_extension='mp4').order_by('resolution').desc().first().download()

# %%
# %pip install -U pytubefix

# %%
from pytubefix import YouTube

url = "https://www.youtube.com/watch?v=dQw4w9WgXcQ"  # public test video
yt = YouTube(url)

print(yt.title)

stream = (
    yt.streams
    .filter(file_extension="mp4", type="video")
    .order_by("resolution")
    .desc()
    .first()
)

if stream is None:
    raise RuntimeError("No downloadable MP4 stream found for this video")

stream.download(output_path="downloads")

# %%
from pytubefix import YouTube
from pathlib import Path

url = "https://www.youtube.com/watch?v=dQw4w9WgXcQ"  # public video
yt = YouTube(url)

print("Title:", yt.title)

stream = (
    yt.streams
    .filter(file_extension="mp4", type="video")
    .order_by("resolution")
    .desc()
    .first()
)

if stream is None:
    raise RuntimeError("No MP4 video stream found for this URL")

out_dir = Path("downloads")
out_dir.mkdir(exist_ok=True)
file_path = stream.download(output_path=str(out_dir))
print("Downloaded:", file_path)

# %%
# %pip install pytubefix

# %%
# No import needed here — `YouTube` is already available from a previous cell.

# Use the imported class to avoid the "unused import" warning
yt = YouTube(url)
print("Title:", yt.title)

stream = (
    yt.streams
    .filter(file_extension="mp4", type="video")
    .order_by("resolution")
    .desc()
    .first()
)

if stream is None:
    raise RuntimeError("No MP4 video stream found for this URL")

file_path = stream.download(output_path=str(out_dir))
print("Downloaded:", file_path)

# %%
from pytube import YouTube

# %%
# %pip install pytube

# %%
from pytube import YouTube
yt = YouTube("https://www.youtube.com/watch?v=TYb4q2DY2tE&list=PLawa3DOhc_40mwnzONKtsndNGk2gN-yrf&index=42")

# %%
from pytube import YouTube
yt = YouTube("https://www.youtube.com/watch?v=TYb4q2DY2tE&list=PLawa3DOhc_40mwnzONKtsndNGk2gN-yrf&index=42")

# %%
yt.streams.filter(file_extension='mp4').order_by('resolution').first()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/miniconda3/lib/python3.13/urllib/request.py:1319, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1318 try:
# -> 1319     h.request(req.get_method(), req.selector, req.data, headers,
#    1320               encode_chunked=req.has_header('Transfer-encoding'))
#    1321 except OSError as err: # timeout error
#
# File ~/miniconda3/lib/python3.13/http/client.py:1338, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1337 """Send a complete request to the server."""
# -> 1338 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~/miniconda3/lib/python3.13/http/client.py:1384, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1383     body = _encode(body, 'body')
# -> 1384 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~/miniconda3/lib/python3.13/http/client.py:1333, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1332     raise CannotSendHeader()
# -> 1333 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~/miniconda3/lib/python3.13/http/client.py:1093, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1092 del self._buffer[:]
# -> 1093 self.send(msg)
#    1095 if message_body is not None:
#    1096
#    1097     # create a consistent interface to message_body
#
# File ~/miniconda3/lib/python3.13/http/client.py:1037, in HTTPConnection.send(self, data)
#    1036 if self.auto_open:
# -> 1037     self.connect()
#    1038 else:
#
# File ~/miniconda3/lib/python3.13/http/client.py:1472, in HTTPSConnection.connect(self)
#    1470 "Connect to a host on a given (SSL) port."
# -> 1472 super().connect()
#    1474 if self._tunnel_host:
#
# File ~/miniconda3/lib/python3.13/http/client.py:1003, in HTTPConnection.connect(self)
#    1002 sys.audit("http.client.connect", self, self.host, self.port)
# -> 1003 self.sock = self._create_connection(
#    1004     (self.host,self.port), self.timeout, self.source_address)
#    1005 # Might fail in OSs that don't implement TCP_NODELAY
#
# File ~/miniconda3/lib/python3.13/socket.py:864, in create_connection(address, timeout, source_address, all_errors)
#     863 if not all_errors:
# --> 864     raise exceptions[0]
#     865 raise ExceptionGroup("create_connection failed", exceptions)
#
# File ~/miniconda3/lib/python3.13/socket.py:849, in create_connection(address, timeout, source_address, all_errors)
#     848     sock.bind(source_address)
# --> 849 sock.connect(sa)
#     850 # Break explicitly a reference cycle
#
# OSError: [Errno 101] Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 yt.streams.filter(file_extension='mp4').order_by('resolution').first()
#
# File ~/miniconda3/lib/python3.13/site-packages/pytube/__main__.py:295, in YouTube.streams(self)
#     289 @property
#     290 def streams(self) -> StreamQuery:
#     291     """Interface to query both adaptive (DASH) and progressive streams.
#     292
#     293     :rtype: :class:`StreamQuery <StreamQuery>`.
#     294     """
# --> 295     self.check_availability()
#     296     return StreamQuery(self.fmt_streams)
#
# File ~/miniconda3/lib/python3.13/site-packages/pytube/__main__.py:210, in YouTube.check_availability(self)
#     204 def check_availability(self):
#     205     """Check whether the video is available.
#     206
#     207     Raises different exceptions based on why the video is unavailable,
#     208     otherwise does nothing.
#     209     """
# --> 210     status, messages = extract.playability_status(self.watch_html)
#     212     for reason in messages:
#     213         if status == 'UNPLAYABLE':
#
# File ~/miniconda3/lib/python3.13/site-packages/pytube/__main__.py:102, in YouTube.watch_html(self)
#     100 if self._watch_html:
#     101     return self._watch_html
# --> 102 self._watch_html = request.get(url=self.watch_url)
#     103 return self._watch_html
#
# File ~/miniconda3/lib/python3.13/site-packages/pytube/request.py:53, in get(url, extra_headers, timeout)
#      51 if extra_headers is None:
#      52     extra_headers = {}
# ---> 53 response = _execute_request(url, headers=extra_headers, timeout=timeout)
#      54 return response.read().decode("utf-8")
#
# File ~/miniconda3/lib/python3.13/site-packages/pytube/request.py:37, in _execute_request(url, method, headers, data, timeout)
#      35 else:
#      36     raise ValueError("Invalid URL")
# ---> 37 return urlopen(request, timeout=timeout)
#
# File ~/miniconda3/lib/python3.13/urllib/request.py:189, in urlopen(url, data, timeout, context)
#     187 else:
#     188     opener = _opener
# --> 189 return opener.open(url, data, timeout)
#
# File ~/miniconda3/lib/python3.13/urllib/request.py:489, in OpenerDirector.open(self, fullurl, data, timeout)
#     486     req = meth(req)
#     488 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 489 response = self._open(req, data)
#     491 # post-process response
#     492 meth_name = protocol+"_response"
#
# File ~/miniconda3/lib/python3.13/urllib/request.py:506, in OpenerDirector._open(self, req, data)
#     503     return result
#     505 protocol = req.type
# --> 506 result = self._call_chain(self.handle_open, protocol, protocol +
#     507                           '_open', req)
#     508 if result:
#     509     return result
#
# File ~/miniconda3/lib/python3.13/urllib/request.py:466, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     464 for handler in handlers:
#     465     func = getattr(handler, meth_name)
# --> 466     result = func(*args)
#     467     if result is not None:
#     468         return result
#
# File ~/miniconda3/lib/python3.13/urllib/request.py:1367, in HTTPSHandler.https_open(self, req)
#    1366 def https_open(self, req):
# -> 1367     return self.do_open(http.client.HTTPSConnection, req,
#    1368                         context=self._context)
#
# File ~/miniconda3/lib/python3.13/urllib/request.py:1322, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1319         h.request(req.get_method(), req.selector, req.data, headers,
#    1320                   encode_chunked=req.has_header('Transfer-encoding'))
#    1321     except OSError as err: # timeout error
# -> 1322         raise URLError(err)
#    1323     r = h.getresponse()
#    1324 except:
#
# URLError: <urlopen error [Errno 101] Network is unreachable>
